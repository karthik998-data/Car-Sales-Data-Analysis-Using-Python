# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel("Car Sales.xlsx")
df
# Out:
#              Car_id       Date Customer Name  Gender  Annual Income  \
# 0      C_CND_000001 2022-01-02     Geraldine    Male          13500
# 1      C_CND_000002 2022-01-02           Gia    Male        1480000
# 2      C_CND_000003 2022-01-02        Gianna    Male        1035000
# 3      C_CND_000004 2022-01-02       Giselle    Male          13500
# 4      C_CND_000005 2022-01-02         Grace    Male        1465000
# ...             ...        ...           ...     ...            ...
# 23901  C_CND_023902 2023-12-31        Martin    Male          13500
# 23902  C_CND_023903 2023-12-31         Jimmy  Female         900000
# 23903  C_CND_023904 2023-12-31          Emma    Male         705000
# 23904  C_CND_023905 2023-12-31      Victoire    Male          13500
# 23905  C_CND_023906 2023-12-31       Donovan    Male        1225000
#
#                                Dealer_Name    Company       Model  \
# 0      Buddy Storbeck's Diesel Service Inc       Ford  Expedition
# ...

# %%
df.shape
# Out:
# (23906, 16)

# %%
df.columns.tolist()
# Out:
# ['Car_id',
#  'Date',
#  'Customer Name',
#  'Gender',
#  'Annual Income',
#  'Dealer_Name',
#  'Company',
#  'Model',
#  'Engine',
#  'Transmission',
#  'Color',
#  'Price ($)',
#  'Dealer_No ',
#  'Body Style',
#  'Phone',
#  'Dealer_Region']

# %%
df['Car_id'].unique()
# Out:
# array(['C_CND_000001', 'C_CND_000002', 'C_CND_000003', ...,
#        'C_CND_023904', 'C_CND_023905', 'C_CND_023906'], dtype=object)

# %%
df['Car_id'].value_counts()
# Out:
# Car_id
# C_CND_000001    1
# C_CND_015935    1
# C_CND_015944    1
# C_CND_015943    1
# C_CND_015942    1
#                ..
# C_CND_007967    1
# C_CND_007966    1
# C_CND_007965    1
# C_CND_007964    1
# C_CND_023906    1
# Name: count, Length: 23906, dtype: int64

# %%
df['Date'].unique()
# Out:
# <DatetimeArray>
# ['2022-01-02 00:00:00', '2022-01-03 00:00:00', '2022-01-04 00:00:00',
#  '2022-01-05 00:00:00', '2022-01-06 00:00:00', '2022-01-09 00:00:00',
#  '2022-01-10 00:00:00', '2022-01-12 00:00:00', '2022-01-13 00:00:00',
#  '2022-01-17 00:00:00',
#  ...
#  '2023-12-20 00:00:00', '2023-12-22 00:00:00', '2023-12-23 00:00:00',
#  '2023-12-24 00:00:00', '2023-12-25 00:00:00', '2023-12-26 00:00:00',
#  '2023-12-27 00:00:00', '2023-12-29 00:00:00', '2023-12-30 00:00:00',
#  '2023-12-31 00:00:00']
# Length: 612, dtype: datetime64[ns]

# %%
df['Date'].value_counts()
# Out:
# Date
# 2023-09-05    190
# 2023-11-10    175
# 2023-12-29    151
# 2023-12-11    140
# 2023-11-24    135
#              ...
# 2022-06-21      5
# 2023-07-12      5
# 2022-12-09      5
# 2022-07-08      5
# 2023-06-29      5
# Name: count, Length: 612, dtype: int64

# %%
df.isnull().sum()
# Out:
# Car_id           0
# Date             0
# Customer Name    1
# Gender           0
# Annual Income    0
# Dealer_Name      0
# Company          0
# Model            0
# Engine           0
# Transmission     0
# Color            0
# Price ($)        0
# Dealer_No        0
# Body Style       0
# Phone            0
# Dealer_Region    0
# dtype: int64

# %%
df[df["Customer Name"].isnull()]
# Out:
#             Car_id       Date Customer Name Gender  Annual Income  \
# 7564  C_CND_007565 2022-11-05           NaN   Male         680000
#
#            Dealer_Name Company       Model                     Engine  \
# 7564  Saab-Belle Dodge   Dodge  Ram Pickup  DoubleÂ Overhead Camshaft
#
#      Transmission       Color  Price ($)  Dealer_No  Body Style    Phone  \
# 7564         Auto  Pale White      45000  60504-7114    Hardtop  7203103
#
#      Dealer_Region
# 7564        Aurora

# %%
df["Customer Name"].fillna("Unknown",inplace = True)
# Out:
# C:\Users\karth\AppData\Local\Temp\ipykernel_20616\652032596.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Customer Name"].fillna("Unknown",inplace = True)

# %%
df[df["Customer Name"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Car_id, Date, Customer Name, Gender, Annual Income, Dealer_Name, Company, Model, Engine, Transmission, Color, Price ($), Dealer_No , Body Style, Phone, Dealer_Region]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23906 entries, 0 to 23905
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_id         23906 non-null  object
#  1   Date           23906 non-null  datetime64[ns]
#  2   Customer Name  23906 non-null  object
#  3   Gender         23906 non-null  object
#  4   Annual Income  23906 non-null  int64
#  5   Dealer_Name    23906 non-null  object
#  6   Company        23906 non-null  object
#  7   Model          23906 non-null  object
#  8   Engine         23906 non-null  object
#  9   Transmission   23906 non-null  object
#  10  Color          23906 non-null  object
#  11  Price ($)      23906 non-null  int64
#  12  Dealer_No      23906 non-null  object
#  13  Body Style     23906 non-null  object
#  14  Phone          23906 non-null  int64
#  15  Dealer_Region  23906 non-null  object
# dtypes: datetime64[ns](1), int64(3), object(12)
# ...

# %%
continous = ["Annual Income","Price ($)"]
categorical = ["Dealer_Region","Body Style","Color","Transmission","Engine","Model","Company","Dealer_Name","Gender","Customer Name"]
df[continous].describe()
# Out:
#        Annual Income     Price ($)
# count   2.390600e+04  23906.000000
# mean    8.308403e+05  28090.247846
# std     7.200064e+05  14788.687608
# min     1.008000e+04   1200.000000
# 25%     3.860000e+05  18001.000000
# 50%     7.350000e+05  23000.000000
# 75%     1.175750e+06  34000.000000
# max     1.120000e+07  85800.000000

# %%
df[categorical].describe()
# Out:
#        Dealer_Region Body Style       Color Transmission  \
# count          23906      23906       23906        23906
# unique             7          5           3            2
# top           Austin        SUV  Pale White         Auto
# freq            4135       6374       11256        12571
#
#                            Engine     Model    Company  \
# count                       23906     23906      23906
# unique                          2       154         30
# top     DoubleÂ Overhead Camshaft  Diamante  Chevrolet
# freq                        12571       418       1819
#
#                                             Dealer_Name Gender Customer Name
# count                                             23906  23906         23906
# unique                                               28      2          3022
# top     Progressive Shippers Cooperative Association No   Male        Thomas
# freq                                               1318  18798            92

# %%
sns.boxplot(df["Annual Income"])
plt.show()

# %%
sns.boxplot(df["Price ($)"])
plt.show()

# %%
df[continous].skew()
# Out:
# Annual Income    1.739838
# Price ($)        1.466316
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.to_excel("cleaned_data_cars.xlsx",index=False)

# %%
df=pd.read_excel("cleaned_data_cars.xlsx")
df
# Out:
#              Car_id       Date Customer Name  Gender  Annual Income  \
# 0      C_CND_000001 2022-01-02     Geraldine    Male          13500
# 1      C_CND_000002 2022-01-02           Gia    Male        1480000
# 2      C_CND_000003 2022-01-02        Gianna    Male        1035000
# 3      C_CND_000004 2022-01-02       Giselle    Male          13500
# 4      C_CND_000005 2022-01-02         Grace    Male        1465000
# ...             ...        ...           ...     ...            ...
# 23901  C_CND_023902 2023-12-31        Martin    Male          13500
# 23902  C_CND_023903 2023-12-31         Jimmy  Female         900000
# 23903  C_CND_023904 2023-12-31          Emma    Male         705000
# 23904  C_CND_023905 2023-12-31      Victoire    Male          13500
# 23905  C_CND_023906 2023-12-31       Donovan    Male        1225000
#
#                                Dealer_Name    Company       Model  \
# 0      Buddy Storbeck's Diesel Service Inc       Ford  Expedition
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23906 entries, 0 to 23905
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_id         23906 non-null  object
#  1   Date           23906 non-null  datetime64[ns]
#  2   Customer Name  23906 non-null  object
#  3   Gender         23906 non-null  object
#  4   Annual Income  23906 non-null  int64
#  5   Dealer_Name    23906 non-null  object
#  6   Company        23906 non-null  object
#  7   Model          23906 non-null  object
#  8   Engine         23906 non-null  object
#  9   Transmission   23906 non-null  object
#  10  Color          23906 non-null  object
#  11  Price ($)      23906 non-null  int64
#  12  Dealer_No      23906 non-null  object
#  13  Body Style     23906 non-null  object
#  14  Phone          23906 non-null  int64
#  15  Dealer_Region  23906 non-null  object
# dtypes: datetime64[ns](1), int64(3), object(12)
# ...

# %%
continous = ["Annual Income","Price ($)"]
categorical = ["Dealer_Region","Body Style","Color","Transmission","Engine","Model","Company","Dealer_Name","Gender","Customer Name"]

# %%
df[continous].describe()
# Out:
#        Annual Income     Price ($)
# count   2.390600e+04  23906.000000
# mean    8.308403e+05  28090.247846
# std     7.200064e+05  14788.687608
# min     1.008000e+04   1200.000000
# 25%     3.860000e+05  18001.000000
# 50%     7.350000e+05  23000.000000
# 75%     1.175750e+06  34000.000000
# max     1.120000e+07  85800.000000

# %%
df[categorical].describe()
# Out:
#        Dealer_Region Body Style       Color Transmission  \
# count          23906      23906       23906        23906
# unique             7          5           3            2
# top           Austin        SUV  Pale White         Auto
# freq            4135       6374       11256        12571
#
#                            Engine     Model    Company  \
# count                       23906     23906      23906
# unique                          2       154         30
# top     DoubleÂ Overhead Camshaft  Diamante  Chevrolet
# freq                        12571       418       1819
#
#                                             Dealer_Name Gender Customer Name
# count                                             23906  23906         23906
# unique                                               28      2          3022
# top     Progressive Shippers Cooperative Association No   Male        Thomas
# freq                                               1318  18798            92

# %%
for i in categorical:
    print(df[i].value_counts(),"\n")
# Out:
# Dealer_Region
# Austin        4135
# Janesville    3821
# Scottsdale    3433
# Pasco         3131
# Aurora        3130
# Middletown    3128
# Greenville    3128
# Name: count, dtype: int64
#
# Body Style
# SUV          6374
# Hatchback    6128
# Sedan        4488
# Passenger    3945
# Hardtop      2971
# Name: count, dtype: int64
#
# Color
# Pale White    11256
# Black          7857
# Red            4793
# Name: count, dtype: int64
#
# Transmission
# Auto      12571
# Manual    11335
# Name: count, dtype: int64
#
# Engine
# DoubleÂ Overhead Camshaft    12571
# Overhead Camshaft            11335
# Name: count, dtype: int64
#
# Model
# Diamante         418
# Silhouette       411
# Prizm            411
# Passat           391
# Ram Pickup       383
#                 ...
# Mirage            19
# Alero             18
# RX300             15
# Avalon            15
# Sebring Conv.     10
# Name: count, Length: 154, dtype: int64
#
# Company
# Chevrolet     1819
# Dodge         1671
# ...

# %%
for i in continous:
    sns.histplot(df[i])
    plt.show()

# %%
df[continous].cov()
# Out:
#                Annual Income     Price ($)
# Annual Income   5.184092e+11  1.284671e+08
# Price ($)       1.284671e+08  2.187053e+08

# %%
df[continous].corr()
# Out:
#                Annual Income  Price ($)
# Annual Income       1.000000   0.012065
# Price ($)           0.012065   1.000000

# %%
plt.figure(figsize=(27,7))
sns.countplot(x="Company",data=df)
# Out:
# <Axes: xlabel='Company', ylabel='count'>

# %%
sns.boxplot(x="Transmission",y="Price ($)",data=df)
# Out:
# <Axes: xlabel='Transmission', ylabel='Price ($)'>

# %%
plt.figure(figsize=(15,7))
sns.scatterplot(x="Annual Income",y="Price ($)",data=df)
plt.ticklabel_format(style='plain',axis='x')

# %%
correlation = df["Annual Income"].corr(df["Price ($)"])
print(correlation)
# Out:
# 0.012064959420296466

# %%
sns.regplot(x="Annual Income",y="Price ($)",data=df)
# Out:
# <Axes: xlabel='Annual Income', ylabel='Price ($)'>
